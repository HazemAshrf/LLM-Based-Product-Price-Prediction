# %% [markdown]
# ## Install Dependencies

# %%
# pip installs

# !pip install -q datasets requests torch peft bitsandbytes transformers trl accelerate sentencepiece wandb matplotlib

# %% [markdown]
# ## Import Libraries

# %%
import os
import re
import math
from tqdm import tqdm
from google.colab import userdata
from huggingface_hub import login
import torch
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, TrainingArguments, set_seed, BitsAndBytesConfig
from datasets import load_dataset, Dataset, DatasetDict
import wandb
from peft import LoraConfig
from trl import SFTTrainer, SFTConfig
from datetime import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# ## Setting Constants and Hyperparameters

# %%
# Constants

BASE_MODEL = "meta-llama/Meta-Llama-3.1-8B"
PROJECT_NAME = "pricer"
HF_USER = "HazemAshraf"

# Data
DATASET_NAME = "ed-donner/pricer-data"
MAX_SEQUENCE_LENGTH = 182

# Run name for saving the model in the hub

RUN_NAME =  f"{datetime.now():%Y-%m-%d_%H.%M.%S}"
PROJECT_RUN_NAME = f"{PROJECT_NAME}-{RUN_NAME}"
HUB_MODEL_NAME = f"{HF_USER}/{PROJECT_RUN_NAME}"

# Hyperparameters for QLoRA

LORA_R = 32
LORA_ALPHA = 64
TARGET_MODULES = ["q_proj", "v_proj", "k_proj", "o_proj"]
LORA_DROPOUT = 0.1
QUANT_4_BIT = True

# Hyperparameters for Training

EPOCHS = 1
BATCH_SIZE = 4
GRADIENT_ACCUMULATION_STEPS = 1
LEARNING_RATE = 1e-4
LR_SCHEDULER_TYPE = 'cosine'
WARMUP_RATIO = 0.03
OPTIMIZER = "paged_adamw_32bit"

# Admin config - note that SAVE_STEPS is how often it will upload to the hub

STEPS = 50
SAVE_STEPS = 500
LOG_TO_WANDB = True

# %matplotlib inline

# %%
HUB_MODEL_NAME
# Out:
# 'HazemAshraf/pricer-2025-03-17_23.10.34'

# %% [markdown]
# ## Log in to HuggingFace and Weights & Biases

# %%
# Log in to HuggingFace

hf_token = userdata.get('hf_token')
login(hf_token, add_to_git_credential=True)

# %%
# Log in to Weights & Biases
wandb_api_key = userdata.get('wandb_api_key')
os.environ["WANDB_API_KEY"] = wandb_api_key
wandb.login()

# Configure Weights & Biases to record against our project
os.environ["WANDB_PROJECT"] = PROJECT_NAME
os.environ["WANDB_LOG_MODEL"] = "checkpoint" if LOG_TO_WANDB else "end"
os.environ["WANDB_WATCH"] = "gradients"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: hazem-ashraf (hazem-ashraf-fau-erlangen-n-rnberg) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %% [markdown]
# ## Load the Dataset

# %%
dataset = load_dataset(DATASET_NAME)
train = dataset['train']
test = dataset['test']
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
# if you wish to reduce the training dataset to 2,000 points instead, then uncomment this line:
train = train.select(range(2000))

# %%
if LOG_TO_WANDB:
  wandb.init(project=PROJECT_NAME, name=RUN_NAME)
# Out:
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250317_231040-7v71arz0</code>
# Syncing run <strong><a href='https://wandb.ai/hazem-ashraf-fau-erlangen-n-rnberg/pricer/runs/7v71arz0' target="_blank">2025-03-17_23.10.34</a></strong> to <a href='https://wandb.ai/hazem-ashraf-fau-erlangen-n-rnberg/pricer' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/hazem-ashraf-fau-erlangen-n-rnberg/pricer' target="_blank">https://wandb.ai/hazem-ashraf-fau-erlangen-n-rnberg/pricer</a>
#  View run at <a href='https://wandb.ai/hazem-ashraf-fau-erlangen-n-rnberg/pricer/runs/7v71arz0' target="_blank">https://wandb.ai/hazem-ashraf-fau-erlangen-n-rnberg/pricer/runs/7v71arz0</a>

# %% [markdown]
# ## Configure Quantization Settings

# %%
# pick the right quantization

if QUANT_4_BIT:
  quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_quant_type="nf4"
  )
else:
  quant_config = BitsAndBytesConfig(
    load_in_8bit=True,
    bnb_8bit_compute_dtype=torch.bfloat16
  )

# %% [markdown]
# ## Load the Tokenizer and Model

# %%
tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    quantization_config=quant_config,
    device_map="auto",
)
base_model.generation_config.pad_token_id = tokenizer.pad_token_id

print(f"Memory footprint: {base_model.get_memory_footprint() / 1e6:.1f} MB")
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Memory footprint: 5591.5 MB

# %% [markdown]
# # Data Collator
#
# It's important that we ensure during Training that we are not trying to train the model to predict the description of products; only their price.
#
# We need to tell the trainer that everything up to "Price is $" is there to give context to the model to predict the next token, but does not need to be learned.
#
# The trainer needs to teach the model to predict the token(s) after "Price is $".
#
# There is a complicated way to do this by setting Masks, but luckily HuggingFace provides a super simple helper class to take care of this for us.

# %%
from trl import DataCollatorForCompletionOnlyLM
response_template = "Price is $"
collator = DataCollatorForCompletionOnlyLM(response_template, tokenizer=tokenizer)

# %% [markdown]
# ## Set up the configuration for Training
#
# We need to create 2 objects:
#
# A LoraConfig object with our hyperparameters for LoRA
#
# An SFTConfig with our overall Training parameters

# %%
# First, specify the configuration parameters for LoRA

lora_parameters = LoraConfig(
    lora_alpha=LORA_ALPHA,
    lora_dropout=LORA_DROPOUT,
    r=LORA_R,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=TARGET_MODULES,
)

# Next, specify the general configuration parameters for training

train_parameters = SFTConfig(
    output_dir=PROJECT_RUN_NAME,
    num_train_epochs=EPOCHS,
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=1,
    eval_strategy="no",
    gradient_accumulation_steps=GRADIENT_ACCUMULATION_STEPS,
    optim=OPTIMIZER,
    save_steps=SAVE_STEPS,
    save_total_limit=10,
    logging_steps=STEPS,
    learning_rate=LEARNING_RATE,
    weight_decay=0.001,
    fp16=False,
    bf16=True,
    max_grad_norm=0.3,
    max_steps=-1,
    warmup_ratio=WARMUP_RATIO,
    group_by_length=True,
    lr_scheduler_type=LR_SCHEDULER_TYPE,
    report_to="wandb" if LOG_TO_WANDB else None,
    run_name=RUN_NAME,
    max_seq_length=MAX_SEQUENCE_LENGTH,
    dataset_text_field="text",
    save_strategy="steps",
    hub_strategy="every_save",
    push_to_hub=True,
    hub_model_id=HUB_MODEL_NAME,
    hub_private_repo=True
)

# And now, the Supervised Fine Tuning Trainer will carry out the fine-tuning
# Given these 2 sets of configuration parameters

fine_tuning = SFTTrainer(
    model=base_model,
    train_dataset=train,
    peft_config=lora_parameters,
    tokenizer=tokenizer,
    args=train_parameters,
    data_collator=collator
)
# Out:
# <ipython-input-13-159c93dc3bd4>:48: FutureWarning: `tokenizer` is deprecated and removed starting from version 0.16.0 for `SFTTrainer.__init__`. Use `processing_class` instead.
#   fine_tuning = SFTTrainer(
# Converting train dataset to ChatML:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Applying chat template to train dataset:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %% [markdown]
# ## Fine-tuning

# %%
# Fine-tune
fine_tuning.train()

# Push our fine-tuned model to Hugging Face
fine_tuning.model.push_to_hub(PROJECT_RUN_NAME, private=True)
print(f"Saved to the hub: {PROJECT_RUN_NAME}")
# Out:
#     <div>
#
#       <progress value='500' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [500/500 1:34:42, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>2.052600</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.983100</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.901100</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.849400</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.912700</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.947400</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.868500</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.854700</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.880700</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.869200</td>
#     </tr>
#   </tbody>
# </table><p>
# wandb: Adding directory to artifact (./pricer-2025-03-17_23.10.34/checkpoint-500)... Done. 6.5s
# README.md:   0%|          | 0.00/1.47k [00:00<?, ?B/s]
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING:huggingface_hub.hf_api:No files have been modified since last commit. Skipping to prevent empty commit.
# Saved to the hub: pricer-2025-03-17_23.10.34

# %%
if LOG_TO_WANDB:
  wandb.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>▁▂▃▃▄▅▆▆▇██</td></tr><tr><td>train/global_step</td><td>▁▂▃▃▄▅▆▆▇██</td></tr><tr><td>train/grad_norm</td><td>▅▁▁█▅▁▂▃▆▄</td></tr><tr><td>train/learning_rate</td><td>██▇▆▅▄▃▂▁▁</td></tr><tr><td>train/loss</td><td>█▆▃▁▃▄▂▁▂▂</td></tr><tr><td>train/mean_token_accuracy</td><td>▁▆▇█▆▇███▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>total_flos</td><td>1.6068144750723072e+16</td></tr><tr><td>train/epoch</td><td>1</td></tr><tr><td>train/global_step</td><td>500</td></tr><tr><td>train/grad_norm</td><td>3.82278</td></tr><tr><td>train/learning_rate</td><td>0</td></tr><tr><td>train/loss</td><td>1.8692</td></tr><tr><td>train/mean_token_accuracy</td><td>0.67</td></tr><tr><td>train_loss</td><td>1.91195</td></tr><tr><td>train_runtime</td><td>5659.2227</td></tr><tr><td>train_samples_per_second</td><td>0.353</td></tr><tr><td>train_steps_per_second</td><td>0.088</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">2025-03-17_23.10.34</strong> at: <a href='https://wandb.ai/hazem-ashraf-fau-erlangen-n-rnberg/pricer/runs/7v71arz0' target="_blank">https://wandb.ai/hazem-ashraf-fau-erlangen-n-rnberg/pricer/runs/7v71arz0</a><br> View project at: <a href='https://wandb.ai/hazem-ashraf-fau-erlangen-n-rnberg/pricer' target="_blank">https://wandb.ai/hazem-ashraf-fau-erlangen-n-rnberg/pricer</a><br>Synced 5 W&B file(s), 0 media file(s), 16 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_231040-7v71arz0/logs</code>

# %% [markdown]
# ## Restart your session!
# ## Predict Product Prices

# %%
import os
import re
import math
from tqdm import tqdm
from google.colab import userdata
from huggingface_hub import login
import torch
import torch.nn.functional as F
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, set_seed
from datasets import load_dataset, Dataset, DatasetDict
from datetime import datetime
from peft import PeftModel
import matplotlib.pyplot as plt

# %%
# Constants

BASE_MODEL = "meta-llama/Meta-Llama-3.1-8B"
PROJECT_NAME = "pricer"
HF_USER = "HazemAshraf" # your HF name here! Or use mine if you just want to reproduce my results.

# The run itself

RUN_NAME = "2025-03-17_23.10.34"
PROJECT_RUN_NAME = f"{PROJECT_NAME}-{RUN_NAME}"
REVISION = None
FINETUNED_MODEL = f"{HF_USER}/{PROJECT_RUN_NAME}"

# Data

DATASET_NAME = "ed-donner/pricer-data"

# Hyperparameters for QLoRA

QUANT_4_BIT = True

# %matplotlib inline

# Used for writing to output in color

GREEN = "\033[92m"
YELLOW = "\033[93m"
RED = "\033[91m"
RESET = "\033[0m"
COLOR_MAP = {"red":RED, "orange": YELLOW, "green": GREEN}

# %%
# Log in to HuggingFace

hf_token = userdata.get('hf_token')
login(hf_token, add_to_git_credential=True)

dataset = load_dataset(DATASET_NAME)
train = dataset['train']
test = dataset['test']
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
test[0]
# Out:
# {'text': "How much does this cost to the nearest dollar?\n\nOEM AC Compressor w/A/C Repair Kit For Ford F150 F-150 V8 & Lincoln Mark LT 2007 2008 - BuyAutoParts NEW\nAs one of the world's largest automotive parts suppliers, our parts are trusted every day by mechanics and vehicle owners worldwide. This A/C Compressor and Components Kit is manufactured and tested to the strictest OE standards for unparalleled performance. Built for trouble-free ownership and 100% visually inspected and quality tested, this A/C Compressor and Components Kit is backed by our 100% satisfaction guarantee. Guaranteed Exact Fit for easy installation 100% BRAND NEW, premium ISO/TS 16949 quality - tested to meet or exceed OEM specifications Engineered for superior durability, backed by industry-leading unlimited-mileage warranty Included in this K\n\nPrice is $",
#  'price': 374.41}

# %% [markdown]
# ## Load the Tokenizer and Model

# %%
if QUANT_4_BIT:
  quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_quant_type="nf4"
  )
else:
  quant_config = BitsAndBytesConfig(
    load_in_8bit=True,
    bnb_8bit_compute_dtype=torch.bfloat16
  )

# %%
# Load the Tokenizer and the Model

tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    quantization_config=quant_config,
    device_map="auto",
)
base_model.generation_config.pad_token_id = tokenizer.pad_token_id

# Load the fine-tuned model with PEFT
if REVISION:
  fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL, revision=REVISION)
else:
  fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL)


print(f"Memory footprint: {fine_tuned_model.get_memory_footprint() / 1e6:.1f} MB")
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# adapter_config.json:   0%|          | 0.00/752 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/109M [00:00<?, ?B/s]
# Memory footprint: 5700.6 MB

# %%
fine_tuned_model
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(128256, 4096)
#         (layers): ModuleList(
#           (0-31): 32 x LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#             (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#           )
#         )
#         (norm): LlamaRMSNorm((4096,), eps=1e-05)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
#     )
#   )
# )

# %%
def extract_price(s):
    if "Price is $" in s:
      contents = s.split("Price is $")[1]
      contents = contents.replace(',','')
      match = re.search(r"[-+]?\d*\.\d+|\d+", contents)
      return float(match.group()) if match else 0
    return 0

# %%
# Original prediction function takes the most likely next token

def model_predict(prompt):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to("cuda")
    attention_mask = torch.ones(inputs.shape, device="cuda")
    outputs = fine_tuned_model.generate(inputs, attention_mask=attention_mask, max_new_tokens=3, num_return_sequences=1)
    response = tokenizer.decode(outputs[0])
    return extract_price(response)

# %%
# An improved prediction function takes a weighted average of the top 3 choices
# This code would be more complex if we couldn't take advantage of the fact
# That Llama generates 1 token for any 3 digit number

top_K = 3

def improved_model_predict(prompt, device="cuda"):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to(device)
    attention_mask = torch.ones(inputs.shape, device=device)

    with torch.no_grad():
        outputs = fine_tuned_model(inputs, attention_mask=attention_mask)
        next_token_logits = outputs.logits[:, -1, :].to('cpu')

    next_token_probs = F.softmax(next_token_logits, dim=-1)
    top_prob, top_token_id = next_token_probs.topk(top_K)
    prices, weights = [], []
    for i in range(top_K):
      predicted_token = tokenizer.decode(top_token_id[0][i])
      probability = top_prob[0][i]
      try:
        result = float(predicted_token)
      except ValueError as e:
        result = 0.0
      if result > 0:
        prices.append(result)
        weights.append(probability)
    if not prices:
      return 0.0, 0.0
    total = sum(weights)
    weighted_prices = [price * weight / total for price, weight in zip(prices, weights)]
    return sum(weighted_prices).item()

# %%
class Tester:

    def __init__(self, predictor, data, title=None, size=250):
        self.predictor = predictor
        self.data = data
        self.title = title or predictor.__name__.replace("_", " ").title()
        self.size = size
        self.guesses = []
        self.truths = []
        self.errors = []
        self.sles = []
        self.colors = []

    def color_for(self, error, truth):
        if error<40 or error/truth < 0.2:
            return "green"
        elif error<80 or error/truth < 0.4:
            return "orange"
        else:
            return "red"

    def run_datapoint(self, i):
        datapoint = self.data[i]
        guess = self.predictor(datapoint["text"])
        truth = datapoint["price"]
        error = abs(guess - truth)
        log_error = math.log(truth+1) - math.log(guess+1)
        sle = log_error ** 2
        color = self.color_for(error, truth)
        title = datapoint["text"].split("\n\n")[1][:20] + "..."
        self.guesses.append(guess)
        self.truths.append(truth)
        self.errors.append(error)
        self.sles.append(sle)
        self.colors.append(color)
        print(f"{COLOR_MAP[color]}{i+1}: Guess: ${guess:,.2f} Truth: ${truth:,.2f} Error: ${error:,.2f} SLE: {sle:,.2f} Item: {title}{RESET}")

    def chart(self, title):
        max_error = max(self.errors)
        plt.figure(figsize=(12, 8))
        max_val = max(max(self.truths), max(self.guesses))
        plt.plot([0, max_val], [0, max_val], color='deepskyblue', lw=2, alpha=0.6)
        plt.scatter(self.truths, self.guesses, s=3, c=self.colors)
        plt.xlabel('Ground Truth')
        plt.ylabel('Model Estimate')
        plt.xlim(0, max_val)
        plt.ylim(0, max_val)
        plt.title(title)
        plt.show()

    def report(self):
        average_error = sum(self.errors) / self.size
        rmsle = math.sqrt(sum(self.sles) / self.size)
        hits = sum(1 for color in self.colors if color=="green")
        title = f"{self.title} Error=${average_error:,.2f} RMSLE={rmsle:,.2f} Hits={hits/self.size*100:.1f}%"
        self.chart(title)

    def run(self):
        self.error = 0
        for i in range(self.size):
            self.run_datapoint(i)
        self.report()

    @classmethod
    def test(cls, function, data):
        cls(function, data).run()

# %%
Tester.test(improved_model_predict, test)
# Out:
# 1: Guess: $273.00 Truth: $374.41 Error: $101.41 SLE: 0.10 Item: OEM AC Compressor w/...
# 2: Guess: $111.94 Truth: $225.11 Error: $113.17 SLE: 0.48 Item: Motorcraft YB3125 Fa...
# 3: Guess: $59.66 Truth: $61.68 Error: $2.02 SLE: 0.00 Item: Dorman Front Washer ...
# 4: Guess: $383.25 Truth: $599.99 Error: $216.74 SLE: 0.20 Item: HP Premium HD Plus T...
# 5: Guess: $37.97 Truth: $16.99 Error: $20.98 SLE: 0.60 Item: Super Switch Pickup ...
# 6: Guess: $13.23 Truth: $31.99 Error: $18.76 SLE: 0.71 Item: Horror Bookmarks, Re...
# 7: Guess: $159.50 Truth: $101.79 Error: $57.71 SLE: 0.20 Item: SK6241 - Stinger 4 G...
# 8: Guess: $283.50 Truth: $289.00 Error: $5.50 SLE: 0.00 Item: Godox ML60Bi LED Lig...
# 9: Guess: $666.50 Truth: $635.86 Error: $30.64 SLE: 0.00 Item: Randall G3 Plus Comb...
# 10: Guess: $80.00 Truth: $65.99 Error: $14.01 SLE: 0.04 Item: HOLDWILL 6 Pack LED ...
# 11: Guess: $253.75 Truth: $254.21 Error: $0.46 SLE: 0.00 Item: Viking Horns 3 Gallo...
# 12: Guess: $265.00 Truth: $412.99 Error: $147.99 SLE: 0.20 Item: CURT 70110 Custom To...
# 13: Guess: $49.88 Truth: $205.50 Error: $155.62 SLE: 1.96 Item: Solar HAMMERED BRONZ...
# 14: Guess: $250.25 Truth: $248.23 Error: $2.02 SLE: 0.00 Item: COSTWAY Electric Tum...
# 15: Guess: $347.75 Truth: $399.00 Error: $51.25 SLE: 0.02 Item: FREE SIGNAL TV Trans...
# 16: Guess: $354.50 Truth: $373.94 Error: $19.44 SLE: 0.00 Item: Bilstein 5100 Monotu...
# 17: Guess: $119.00 Truth: $92.89 Error: $26.11 SLE: 0.06 Item: Sangean K-200 Multi-...
# 18: Guess: $90.38 Truth: $51.99 Error: $38.38 SLE: 0.30 Item: Charles Leonard Magn...
# 19: Guess: $210.50 Truth: $179.00 Error: $31.50 SLE: 0.03 Item: Gigabyte AMD Radeon ...
# 20: Guess: $8.98 Truth: $19.42 Error: $10.44 SLE: 0.51 Item: 3dRose LLC 8 x 8 x 0...
# 21: Guess: $527.00 Truth: $539.95 Error: $12.95 SLE: 0.00 Item: ROKINON 85mm F1.4 Au...
# 22: Guess: $109.44 Truth: $147.67 Error: $38.23 SLE: 0.09 Item: Headlight Assembly C...
# 23: Guess: $14.23 Truth: $24.99 Error: $10.76 SLE: 0.29 Item: ASI NAUTICAL 2.5 Inc...
# 24: Guess: $102.12 Truth: $149.00 Error: $46.88 SLE: 0.14 Item: Behringer TUBE OVERD...
# 25: Guess: $9.70 Truth: $16.99 Error: $7.29 SLE: 0.27 Item: Fun Express Insect F...
# 26: Guess: $10.34 Truth: $7.99 Error: $2.35 SLE: 0.05 Item: WAFJAMF Roller Stamp...
# 27: Guess: $174.62 Truth: $199.99 Error: $25.37 SLE: 0.02 Item: Capulina Tiffany Flo...
# 28: Guess: $221.88 Truth: $251.45 Error: $29.57 SLE: 0.02 Item: Apple Watch Series 6...
# 29: Guess: $97.62 Truth: $231.62 Error: $134.00 SLE: 0.74 Item: ICON 01725 Tandem Ax...
# 30: Guess: $148.50 Truth: $135.00 Error: $13.50 SLE: 0.01 Item: SanDisk 128GB Ultra ...
# 31: Guess: $305.25 Truth: $356.62 Error: $51.37 SLE: 0.02 Item: Velvac - 715427
# 2020...
# 32: Guess: $220.00 Truth: $257.99 Error: $37.99 SLE: 0.03 Item: TCMT Passenger Backr...
# 33: Guess: $35.03 Truth: $27.99 Error: $7.04 SLE: 0.05 Item: Alnicov 63.5MM Brass...
# 34: Guess: $100.50 Truth: $171.20 Error: $70.70 SLE: 0.28 Item: Subaru Forester Outb...
# 35: Guess: $271.50 Truth: $225.00 Error: $46.50 SLE: 0.04 Item: Richmond Auto Uphols...
# 36: Guess: $153.50 Truth: $105.00 Error: $48.50 SLE: 0.14 Item: AP-39 Automotive Pai...
# 37: Guess: $252.25 Truth: $299.99 Error: $47.74 SLE: 0.03 Item: Road Top Wireless Ca...
# 38: Guess: $403.50 Truth: $535.09 Error: $131.59 SLE: 0.08 Item: Gibson Performance E...
# 39: Guess: $23.77 Truth: $12.33 Error: $11.44 SLE: 0.38 Item: Bella Tunno Happy Li...
# 40: Guess: $130.38 Truth: $84.99 Error: $45.39 SLE: 0.18 Item: CANMORE H300 Handhel...
# 41: Guess: $13.58 Truth: $15.99 Error: $2.41 SLE: 0.02 Item: DCPOWER AC Adapter C...
# 42: Guess: $25.00 Truth: $62.44 Error: $37.44 SLE: 0.80 Item: Sharp, Commercial De...
# 43: Guess: $124.19 Truth: $82.99 Error: $41.20 SLE: 0.16 Item: Melissa & Doug Lifel...
# 44: Guess: $346.00 Truth: $599.95 Error: $253.95 SLE: 0.30 Item: Sony SSCS8 2-Way Cen...
# 45: Guess: $342.00 Truth: $194.99 Error: $147.01 SLE: 0.31 Item: ASUS Chromebook CX1,...
# 46: Guess: $376.75 Truth: $344.95 Error: $31.80 SLE: 0.01 Item: FiiO X7 32GB Hi-Res ...
# 47: Guess: $42.00 Truth: $37.99 Error: $4.01 SLE: 0.01 Item: TORRO Leather Case C...
# 48: Guess: $262.75 Truth: $224.35 Error: $38.40 SLE: 0.02 Item: Universal Air Condit...
# 49: Guess: $397.50 Truth: $814.00 Error: $416.50 SLE: 0.51 Item: Street Series Stainl...
# 50: Guess: $349.25 Truth: $439.88 Error: $90.63 SLE: 0.05 Item: Lenovo IdeaPad 3 Lap...
# 51: Guess: $348.75 Truth: $341.43 Error: $7.32 SLE: 0.00 Item: Access Bed Covers To...
# 52: Guess: $29.92 Truth: $46.78 Error: $16.86 SLE: 0.19 Item: G.I. JOE Hasbro 3 3/...
# 53: Guess: $139.75 Truth: $171.44 Error: $31.69 SLE: 0.04 Item: T&S Brass Double Pan...
# 54: Guess: $253.38 Truth: $458.00 Error: $204.62 SLE: 0.35 Item: ZTUOAUMA Fuel Inject...
# 55: Guess: $157.75 Truth: $130.75 Error: $27.00 SLE: 0.03 Item: Hp Prime Graphing Ca...
# 56: Guess: $49.94 Truth: $83.81 Error: $33.87 SLE: 0.26 Item: Lowrance Nmea 2000 2...
# 57: Guess: $166.12 Truth: $386.39 Error: $220.26 SLE: 0.71 Item: Jeep Genuine Accesso...
# 58: Guess: $128.25 Truth: $169.00 Error: $40.75 SLE: 0.08 Item: GODOX CB-06 Hard Car...
# 59: Guess: $8.04 Truth: $17.95 Error: $9.91 SLE: 0.55 Item: Au-Tomotive Gold, IN...
# 60: Guess: $177.12 Truth: $269.00 Error: $91.88 SLE: 0.17 Item: Snailfly Black Roof ...
# 61: Guess: $69.12 Truth: $77.77 Error: $8.64 SLE: 0.01 Item: KING SHA Anti Glare ...
# 62: Guess: $153.50 Truth: $88.99 Error: $64.51 SLE: 0.29 Item: APS Compatible with ...
# 63: Guess: $225.38 Truth: $364.41 Error: $139.04 SLE: 0.23 Item: Wilwood Engineering ...
# 64: Guess: $151.88 Truth: $127.03 Error: $24.84 SLE: 0.03 Item: ACDelco Gold Starter...
# 65: Guess: $351.75 Truth: $778.95 Error: $427.20 SLE: 0.63 Item: UWS Matte Black Heav...
# 66: Guess: $295.00 Truth: $206.66 Error: $88.34 SLE: 0.13 Item: Dell Latitude E5440 ...
# 67: Guess: $59.56 Truth: $35.94 Error: $23.62 SLE: 0.24 Item: (Plug and Play) Spar...
# 68: Guess: $235.50 Truth: $149.00 Error: $86.50 SLE: 0.21 Item: The Ultimate Roadsid...
# 69: Guess: $251.25 Truth: $251.98 Error: $0.73 SLE: 0.00 Item: Brand New 18 x 8.5 R...
# 70: Guess: $131.62 Truth: $160.00 Error: $28.38 SLE: 0.04 Item: Headlight Headlamp L...
# 71: Guess: $35.03 Truth: $39.99 Error: $4.96 SLE: 0.02 Item: Lilo And Stitch Delu...
# 72: Guess: $175.75 Truth: $362.41 Error: $186.66 SLE: 0.52 Item: AC Compressor & A/C ...
# 73: Guess: $130.00 Truth: $344.00 Error: $214.00 SLE: 0.94 Item: House Of Troy Pinnac...
# 74: Guess: $18.66 Truth: $25.09 Error: $6.43 SLE: 0.08 Item: Juno T29 WH Floating...
# 75: Guess: $130.38 Truth: $175.95 Error: $45.57 SLE: 0.09 Item: Sherman GO-PARTS - f...
# 76: Guess: $158.62 Truth: $132.64 Error: $25.99 SLE: 0.03 Item: Roland RPU-3 Electro...
# 77: Guess: $347.50 Truth: $422.99 Error: $75.49 SLE: 0.04 Item: Rockland VMI14 12,00...
# 78: Guess: $152.38 Truth: $146.48 Error: $5.90 SLE: 0.00 Item: Max Advanced Brakes ...
# 79: Guess: $161.88 Truth: $156.83 Error: $5.04 SLE: 0.00 Item: Quality-Built 11030 ...
# 80: Guess: $128.75 Truth: $251.99 Error: $123.24 SLE: 0.45 Item: Lucida LG-510 Studen...
# 81: Guess: $189.75 Truth: $940.33 Error: $750.58 SLE: 2.55 Item: Longacre Aluminum Tu...
# 82: Guess: $36.34 Truth: $52.99 Error: $16.65 SLE: 0.14 Item: Motion Pro Adjustabl...
# 83: Guess: $108.75 Truth: $219.95 Error: $111.20 SLE: 0.49 Item: Glyph Thunderbolt 3 ...
# 84: Guess: $252.88 Truth: $441.03 Error: $188.15 SLE: 0.31 Item: TOYO Open Country MT...
# 85: Guess: $219.12 Truth: $168.98 Error: $50.15 SLE: 0.07 Item: Razer Seiren X USB S...
# 86: Guess: $3.05 Truth: $2.49 Error: $0.56 SLE: 0.02 Item: Happy Birthday to Da...
# 87: Guess: $193.00 Truth: $98.62 Error: $94.38 SLE: 0.44 Item: Little Tikes My Real...
# 88: Guess: $316.00 Truth: $256.95 Error: $59.05 SLE: 0.04 Item: Studio M Peace and H...
# 89: Guess: $14.34 Truth: $30.99 Error: $16.65 SLE: 0.54 Item: MyVolts 12V Power Su...
# 90: Guess: $280.50 Truth: $569.84 Error: $289.34 SLE: 0.50 Item: Dell Latitude 7212 R...
# 91: Guess: $131.38 Truth: $177.99 Error: $46.62 SLE: 0.09 Item: Covermates Contour F...
# 92: Guess: $349.25 Truth: $997.99 Error: $648.74 SLE: 1.10 Item: Westin Black HDX Gri...
# 93: Guess: $251.75 Truth: $219.00 Error: $32.75 SLE: 0.02 Item: Fieldpiece JL2 Job L...
# 94: Guess: $251.00 Truth: $225.55 Error: $25.45 SLE: 0.01 Item: hansgrohe Talis S Mo...
# 95: Guess: $135.50 Truth: $495.95 Error: $360.45 SLE: 1.67 Item: G-Technology G-SPEED...
# 96: Guess: $235.00 Truth: $942.37 Error: $707.37 SLE: 1.92 Item: DreamLine Shower Doo...
# 97: Guess: $6.37 Truth: $1.94 Error: $4.43 SLE: 0.84 Item: Sanctuary Square Bac...
# 98: Guess: $214.25 Truth: $284.34 Error: $70.09 SLE: 0.08 Item: Pelican Protector 17...
# 99: Guess: $198.50 Truth: $171.90 Error: $26.60 SLE: 0.02 Item: Brock Replacement Dr...
# 100: Guess: $196.75 Truth: $144.99 Error: $51.76 SLE: 0.09 Item: Carlinkit Ai Box Min...
# 101: Guess: $284.75 Truth: $470.47 Error: $185.72 SLE: 0.25 Item: StarDot YouTube Live...
# 102: Guess: $50.47 Truth: $66.95 Error: $16.48 SLE: 0.08 Item: Atomic Compatible ME...
# 103: Guess: $132.50 Truth: $117.00 Error: $15.50 SLE: 0.02 Item: Bandai Awakening of ...
# 104: Guess: $273.25 Truth: $172.14 Error: $101.11 SLE: 0.21 Item: Fit System 62135G Pa...
# 105: Guess: $299.75 Truth: $392.74 Error: $92.99 SLE: 0.07 Item: Black Horse Black Al...
# 106: Guess: $13.58 Truth: $16.99 Error: $3.41 SLE: 0.04 Item: Dearsun Twinkle Star...
# 107: Guess: $1.98 Truth: $1.34 Error: $0.64 SLE: 0.06 Item: Pokemon - Gallade Sp...
# 108: Guess: $250.38 Truth: $349.98 Error: $99.61 SLE: 0.11 Item: Ibanez GIO Series Cl...
# 109: Guess: $301.50 Truth: $370.71 Error: $69.21 SLE: 0.04 Item: Set 2 Heavy Duty 12 ...
# 110: Guess: $69.94 Truth: $65.88 Error: $4.06 SLE: 0.00 Item: Hairpin Table Legs 2...
# 111: Guess: $134.75 Truth: $229.99 Error: $95.24 SLE: 0.28 Item: Marada Racing Seat w...
# 112: Guess: $8.00 Truth: $9.14 Error: $1.14 SLE: 0.01 Item: Remington Industries...
# 113: Guess: $449.50 Truth: $199.00 Error: $250.50 SLE: 0.66 Item: Acer Ultrabook, Inte...
# 114: Guess: $251.50 Truth: $109.99 Error: $141.51 SLE: 0.68 Item: ICBEAMER 7 RGB LED H...
# 115: Guess: $263.75 Truth: $570.42 Error: $306.67 SLE: 0.59 Item: R1 Concepts Front Re...
# 116: Guess: $182.50 Truth: $279.99 Error: $97.49 SLE: 0.18 Item: Camplux 2.64 GPM Tan...
# 117: Guess: $18.00 Truth: $30.99 Error: $12.99 SLE: 0.27 Item: KNOKLOCK 10 Pack 3.7...
# 118: Guess: $35.06 Truth: $31.99 Error: $3.07 SLE: 0.01 Item: Valley Enterprises Y...
# 119: Guess: $28.62 Truth: $15.90 Error: $12.72 SLE: 0.32 Item: G9 LED Light 100W re...
# 120: Guess: $97.31 Truth: $45.99 Error: $51.32 SLE: 0.54 Item: ZCHAOZ 4 Lights Anti...
# 121: Guess: $131.88 Truth: $113.52 Error: $18.36 SLE: 0.02 Item: Honeywell Honeywell ...
# 122: Guess: $299.25 Truth: $516.99 Error: $217.74 SLE: 0.30 Item: Patriot Exhaust 1-7/...
# 123: Guess: $129.12 Truth: $196.99 Error: $67.87 SLE: 0.18 Item: Fitrite Autopart New...
# 124: Guess: $9.66 Truth: $46.55 Error: $36.89 SLE: 2.23 Item: Technical Precision ...
# 125: Guess: $193.88 Truth: $356.99 Error: $163.12 SLE: 0.37 Item: Covercraft Carhartt ...
# 126: Guess: $314.25 Truth: $319.95 Error: $5.70 SLE: 0.00 Item: Sennheiser SD Pro 2 ...
# 127: Guess: $112.00 Truth: $96.06 Error: $15.94 SLE: 0.02 Item: Hitachi Mass Air Flo...
# 128: Guess: $347.50 Truth: $190.99 Error: $156.51 SLE: 0.36 Item: AmScope LED Cordless...
# 129: Guess: $117.38 Truth: $257.95 Error: $140.57 SLE: 0.61 Item: Front Left Driver Si...
# 130: Guess: $96.44 Truth: $62.95 Error: $33.49 SLE: 0.18 Item: Premium Replica Hubc...
# 131: Guess: $35.12 Truth: $47.66 Error: $12.53 SLE: 0.09 Item: Excellerations Phoni...
# 132: Guess: $194.25 Truth: $226.99 Error: $32.74 SLE: 0.02 Item: RC4WD BigDog Dual Ax...
# 133: Guess: $224.38 Truth: $359.95 Error: $135.57 SLE: 0.22 Item: Unknown Stage 2 Clut...
# 134: Guess: $41.81 Truth: $78.40 Error: $36.59 SLE: 0.38 Item: Dodge Ram 1500 Mopar...
# 135: Guess: $224.00 Truth: $172.77 Error: $51.23 SLE: 0.07 Item: Pro Comp Alloys Seri...
# 136: Guess: $263.50 Truth: $316.45 Error: $52.95 SLE: 0.03 Item: Detroit Axle - Front...
# 137: Guess: $113.50 Truth: $87.99 Error: $25.51 SLE: 0.06 Item: ECCPP Rear Wheel Axl...
# 138: Guess: $350.50 Truth: $226.63 Error: $123.87 SLE: 0.19 Item: Dell Latitude E6520 ...
# 139: Guess: $49.69 Truth: $31.49 Error: $18.20 SLE: 0.20 Item: F FIERCE CYCLE 251pc...
# 140: Guess: $175.50 Truth: $196.00 Error: $20.50 SLE: 0.01 Item: Flash Furniture 4 Pk...
# 141: Guess: $44.00 Truth: $78.40 Error: $34.40 SLE: 0.32 Item: B&M 30287 Throttle V...
# 142: Guess: $126.94 Truth: $116.25 Error: $10.69 SLE: 0.01 Item: Gates TCK226 PowerGr...
# 143: Guess: $170.75 Truth: $112.78 Error: $57.97 SLE: 0.17 Item: Monroe Shocks & Stru...
# 144: Guess: $49.69 Truth: $27.32 Error: $22.37 SLE: 0.34 Item: Feit Electric 35W EQ...
# 145: Guess: $118.75 Truth: $145.91 Error: $27.16 SLE: 0.04 Item: Yellow Jacket 2806 C...
# 146: Guess: $112.00 Truth: $171.09 Error: $59.09 SLE: 0.18 Item: Garage-Pro Tailgate ...
# 147: Guess: $97.38 Truth: $167.95 Error: $70.57 SLE: 0.29 Item: 3M Perfect It Buffin...
# 148: Guess: $41.56 Truth: $28.49 Error: $13.07 SLE: 0.13 Item: Chinese Style Dollho...
# 149: Guess: $118.62 Truth: $122.23 Error: $3.61 SLE: 0.00 Item: Generic NRG Innovati...
# 150: Guess: $80.56 Truth: $32.99 Error: $47.57 SLE: 0.77 Item: Learning Resources C...
# 151: Guess: $61.72 Truth: $71.20 Error: $9.48 SLE: 0.02 Item: Bosch Automotive 154...
# 152: Guess: $52.84 Truth: $112.75 Error: $59.91 SLE: 0.56 Item: Case of 24-2 Inch Bl...
# 153: Guess: $117.75 Truth: $142.43 Error: $24.68 SLE: 0.04 Item: MOCA Engine Water Pu...
# 154: Guess: $298.75 Truth: $398.99 Error: $100.24 SLE: 0.08 Item: SAREMAS Foot Step Ba...
# 155: Guess: $501.50 Truth: $449.00 Error: $52.50 SLE: 0.01 Item: Gretsch G9210 Square...
# 156: Guess: $294.50 Truth: $189.00 Error: $105.50 SLE: 0.20 Item: NikoMaku Mirror Dash...
# 157: Guess: $152.12 Truth: $120.91 Error: $31.22 SLE: 0.05 Item: Fenix HP25R v2.0 USB...
# 158: Guess: $273.50 Truth: $203.53 Error: $69.97 SLE: 0.09 Item: R&L Racing Heavy Dut...
# 159: Guess: $315.75 Truth: $349.99 Error: $34.24 SLE: 0.01 Item: Garmin GPSMAP 64sx, ...
# 160: Guess: $8.03 Truth: $34.35 Error: $26.32 SLE: 1.86 Item: Brown 5-7/8 X 8-1/2 ...
# 161: Guess: $284.50 Truth: $384.99 Error: $100.49 SLE: 0.09 Item: GAOMON PD2200 Pen Di...
# 162: Guess: $264.75 Truth: $211.00 Error: $53.75 SLE: 0.05 Item: VXMOTOR for 97-03 Fo...
# 163: Guess: $234.00 Truth: $129.00 Error: $105.00 SLE: 0.35 Item: HP EliteBook 2540p I...
# 164: Guess: $9.74 Truth: $111.45 Error: $101.71 SLE: 5.51 Item: Green EPX Mixing Noz...
# 165: Guess: $6.94 Truth: $81.12 Error: $74.18 SLE: 5.46 Item: Box Partners 6 1/4 x...
# 166: Guess: $299.50 Truth: $457.08 Error: $157.58 SLE: 0.18 Item: Vixen Air 1/2 NPT Ai...
# 167: Guess: $128.62 Truth: $49.49 Error: $79.13 SLE: 0.89 Item: Smart Floor Lamp, Mu...
# 168: Guess: $36.34 Truth: $80.56 Error: $44.22 SLE: 0.61 Item: SOZG 324mm Wheelbase...
# 169: Guess: $263.75 Truth: $278.39 Error: $14.64 SLE: 0.00 Item: Mickey Thompson ET S...
# 170: Guess: $274.50 Truth: $364.50 Error: $90.00 SLE: 0.08 Item: Pirelli 106W XL RFT ...
# 171: Guess: $153.25 Truth: $378.99 Error: $225.74 SLE: 0.81 Item: Torklift C3212 Rear ...
# 172: Guess: $272.00 Truth: $165.28 Error: $106.72 SLE: 0.25 Item: Cardone Remanufactur...
# 173: Guess: $97.62 Truth: $56.74 Error: $40.88 SLE: 0.29 Item: Kidde AccessPoint 00...
# 174: Guess: $190.00 Truth: $307.95 Error: $117.95 SLE: 0.23 Item: 3M Protecta Self Ret...
# 175: Guess: $52.62 Truth: $38.00 Error: $14.62 SLE: 0.10 Item: Plantronics Wired He...
# 176: Guess: $63.44 Truth: $53.00 Error: $10.44 SLE: 0.03 Item: Logitech K750 Wirele...
# 177: Guess: $430.50 Truth: $498.00 Error: $67.50 SLE: 0.02 Item: Olympus PEN E-PL9 Bo...
# 178: Guess: $112.00 Truth: $53.99 Error: $58.01 SLE: 0.52 Item: Beck/Arnley Hub & Be...
# 179: Guess: $302.00 Truth: $350.00 Error: $48.00 SLE: 0.02 Item: Eibach Pro-Kit Perfo...
# 180: Guess: $354.25 Truth: $299.95 Error: $54.30 SLE: 0.03 Item: LEGO DC Batman 1989 ...
# 181: Guess: $129.88 Truth: $94.93 Error: $34.94 SLE: 0.10 Item: Kingston Brass Resto...
# 182: Guess: $347.75 Truth: $379.00 Error: $31.25 SLE: 0.01 Item: Polk Vanishing Serie...
# 183: Guess: $313.25 Truth: $299.95 Error: $13.30 SLE: 0.00 Item: Spec-D Tuning LED Pr...
# 184: Guess: $17.03 Truth: $24.99 Error: $7.96 SLE: 0.13 Item: RICHMOND & FINCH Air...
# 185: Guess: $58.31 Truth: $41.04 Error: $17.27 SLE: 0.12 Item: LFA Industries - mm ...
# 186: Guess: $131.50 Truth: $327.90 Error: $196.40 SLE: 0.83 Item: SAUTVS LED Headlight...
# 187: Guess: $18.03 Truth: $10.99 Error: $7.04 SLE: 0.21 Item: 2 Pack Combo Womens ...
# 188: Guess: $13.63 Truth: $14.99 Error: $1.36 SLE: 0.01 Item: Arepa - Venezuelan c...
# 189: Guess: $15.30 Truth: $84.95 Error: $69.65 SLE: 2.76 Item: Schlage Lock Company...
# 190: Guess: $118.44 Truth: $111.00 Error: $7.44 SLE: 0.00 Item: Techni Mobili White ...
# 191: Guess: $131.12 Truth: $123.73 Error: $7.39 SLE: 0.00 Item: Special Lite Product...
# 192: Guess: $125.88 Truth: $557.38 Error: $431.50 SLE: 2.20 Item: Tascam Digital Porta...
# 193: Guess: $96.75 Truth: $95.55 Error: $1.20 SLE: 0.00 Item: Glow Lighting Vista ...
# 194: Guess: $132.00 Truth: $154.00 Error: $22.00 SLE: 0.02 Item: Z3 Wind Deflector, S...
# 195: Guess: $347.50 Truth: $198.99 Error: $148.51 SLE: 0.31 Item: Olympus E-20 5MP Dig...
# 196: Guess: $217.88 Truth: $430.44 Error: $212.56 SLE: 0.46 Item: PHYNEDI 1 1000 World...
# 197: Guess: $24.92 Truth: $45.67 Error: $20.75 SLE: 0.35 Item: YANGHUAN Unstable Un...
# 198: Guess: $254.00 Truth: $249.00 Error: $5.00 SLE: 0.00 Item: Interlogix NetworX T...
# 199: Guess: $31.39 Truth: $42.99 Error: $11.60 SLE: 0.09 Item: Steering Damper,Univ...
# 200: Guess: $120.75 Truth: $181.33 Error: $60.58 SLE: 0.16 Item: Amprobe TIC 410A Hot...
# 201: Guess: $1.37 Truth: $6.03 Error: $4.66 SLE: 1.18 Item: MyCableMart 3.5mm Pl...
# 202: Guess: $56.12 Truth: $29.99 Error: $26.14 SLE: 0.37 Item: OtterBox + Pop Symme...
# 203: Guess: $510.75 Truth: $899.00 Error: $388.25 SLE: 0.32 Item: Dell XPS Desktop ( I...
# 204: Guess: $294.75 Truth: $399.99 Error: $105.24 SLE: 0.09 Item: Franklin Iron Works ...
# 205: Guess: $19.70 Truth: $4.66 Error: $15.04 SLE: 1.68 Item: Avery Legal Dividers...
# 206: Guess: $161.88 Truth: $261.41 Error: $99.54 SLE: 0.23 Item: Moen 8346 Commercial...
# 207: Guess: $162.38 Truth: $136.97 Error: $25.41 SLE: 0.03 Item: Carlisle Versa Trail...
# 208: Guess: $96.69 Truth: $79.00 Error: $17.69 SLE: 0.04 Item: SUNWAYFOTO 44mm Trip...
# 209: Guess: $257.00 Truth: $444.99 Error: $187.99 SLE: 0.30 Item: NanoBeam AC 4 Units ...
# 210: Guess: $349.25 Truth: $411.94 Error: $62.69 SLE: 0.03 Item: WULF 4 Front 2 Rear ...
# 211: Guess: $221.00 Truth: $148.40 Error: $72.60 SLE: 0.16 Item: Alera ALEVABFMC Vale...
# 212: Guess: $135.00 Truth: $244.99 Error: $109.99 SLE: 0.35 Item: YU-GI-OH! Ignition A...
# 213: Guess: $128.50 Truth: $86.50 Error: $42.00 SLE: 0.15 Item: 48 x 36 Extra-Large ...
# 214: Guess: $196.00 Truth: $297.95 Error: $101.95 SLE: 0.17 Item: Dell Latitude D620 R...
# 215: Guess: $484.00 Truth: $399.99 Error: $84.01 SLE: 0.04 Item: acer Aspire 5 Laptop...
# 216: Guess: $147.12 Truth: $599.00 Error: $451.88 SLE: 1.96 Item: Elk 30 by 6-Inch Viv...
# 217: Guess: $69.19 Truth: $105.99 Error: $36.80 SLE: 0.18 Item: Barbie Top Model Dol...
# 218: Guess: $430.00 Truth: $689.00 Error: $259.00 SLE: 0.22 Item: Danby Designer 20-In...
# 219: Guess: $297.00 Truth: $404.99 Error: $107.99 SLE: 0.10 Item: FixtureDisplays® Met...
# 220: Guess: $160.38 Truth: $207.76 Error: $47.38 SLE: 0.07 Item: ACDelco GM Original ...
# 221: Guess: $263.50 Truth: $171.82 Error: $91.68 SLE: 0.18 Item: EBC Premium Street B...
# 222: Guess: $347.50 Truth: $293.24 Error: $54.26 SLE: 0.03 Item: FXR Men's Boost FX J...
# 223: Guess: $189.62 Truth: $374.95 Error: $185.32 SLE: 0.46 Item: SuperATV Scratch Res...
# 224: Guess: $97.00 Truth: $111.99 Error: $14.99 SLE: 0.02 Item: SBU 3 Layer All Weat...
# 225: Guess: $17.97 Truth: $42.99 Error: $25.02 SLE: 0.71 Item: 2 Pack Outdoor Broch...
# 226: Guess: $170.75 Truth: $116.71 Error: $54.04 SLE: 0.14 Item: Monroe Shocks & Stru...
# 227: Guess: $298.75 Truth: $118.61 Error: $180.14 SLE: 0.84 Item: Elements of Design M...
# 228: Guess: $160.50 Truth: $147.12 Error: $13.38 SLE: 0.01 Item: GM Genuine Parts Air...
# 229: Guess: $175.00 Truth: $119.99 Error: $55.01 SLE: 0.14 Item: Baseus USB C Docking...
# 230: Guess: $244.00 Truth: $369.98 Error: $125.98 SLE: 0.17 Item: Whitehall™ Personali...
# 231: Guess: $240.38 Truth: $315.55 Error: $75.18 SLE: 0.07 Item: Pro Circuit Works Pi...
# 232: Guess: $315.00 Truth: $190.99 Error: $124.01 SLE: 0.25 Item: HYANKA 15 1200W Prof...
# 233: Guess: $119.75 Truth: $155.00 Error: $35.25 SLE: 0.07 Item: Bluetooth X6BT Card ...
# 234: Guess: $273.25 Truth: $349.99 Error: $76.74 SLE: 0.06 Item: AIRAID Cold Air Inta...
# 235: Guess: $197.88 Truth: $249.99 Error: $52.12 SLE: 0.05 Item: Bostingner Shower Fa...
# 236: Guess: $96.94 Truth: $42.99 Error: $53.95 SLE: 0.64 Item: PIT66 Front Bumper T...
# 237: Guess: $18.36 Truth: $17.99 Error: $0.37 SLE: 0.00 Item: Caseology Bumpy Comp...
# 238: Guess: $297.75 Truth: $425.00 Error: $127.25 SLE: 0.13 Item: Fleck 2510 Timer Mec...
# 239: Guess: $293.50 Truth: $249.99 Error: $43.51 SLE: 0.03 Item: Haloview MC7108 Wire...
# 240: Guess: $42.12 Truth: $138.23 Error: $96.10 SLE: 1.37 Item: Schmidt Spiele - Man...
# 241: Guess: $273.00 Truth: $414.99 Error: $141.99 SLE: 0.17 Item: Corsa 14333 Tip Kit ...
# 242: Guess: $112.00 Truth: $168.28 Error: $56.28 SLE: 0.16 Item: Hoshizaki FM116A Fan...
# 243: Guess: $131.50 Truth: $199.99 Error: $68.49 SLE: 0.17 Item: BAINUO Antler Chande...
# 244: Guess: $120.38 Truth: $126.70 Error: $6.33 SLE: 0.00 Item: DNA MOTORING Smoke L...
# 245: Guess: $9.59 Truth: $5.91 Error: $3.68 SLE: 0.18 Item: Wera Stainless 3840/...
# 246: Guess: $251.00 Truth: $193.06 Error: $57.94 SLE: 0.07 Item: Celestron - PowerSee...
# 247: Guess: $350.25 Truth: $249.99 Error: $100.26 SLE: 0.11 Item: NHOPEEW Android Car ...
# 248: Guess: $49.88 Truth: $64.12 Error: $14.25 SLE: 0.06 Item: Other Harmonica A)
# F...
# 249: Guess: $130.25 Truth: $114.99 Error: $15.26 SLE: 0.02 Item: Harley Air Filter Ve...
# 250: Guess: $350.50 Truth: $926.00 Error: $575.50 SLE: 0.94 Item: Elite Screens Edge F...
